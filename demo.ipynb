# %% [markdown]
# ## Basic Usage

# %%
import openslide_dataset
import cv2
import numpy as np
import math as m
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# load a dataset
dataset = openslide_dataset.LabeledOpenSlideDataset('./test.txt', './test_slides/', 512, 256)
# Out:
# loaded 1 slide(s).
# there are total 2 regions with total area of 3125000 px^2.
# 3125000.0 / 512^2 = 11.920928955078125 ... patches/epoch is set to 12.

# %%
# generate a random patche
result, label = dataset.get_example(0)
plt.imshow(result.transpose((1,2,0)))
